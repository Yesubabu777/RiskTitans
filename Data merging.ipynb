# %%
import pandas as pd

# %%
df_2012=pd.read_csv('ECNBASIC2012.EC1262A1-Data.csv')
df_2017=pd.read_csv('ECNBASIC2017.EC1700BASIC-Data.csv',low_memory=False)
df_2022=pd.read_csv('ECNBASIC2022.EC2262BASIC-Data.csv',low_memory=False)

# %%
df_2012
# Out:
#                           GEO_ID                      NAME        NAICS2012  \
# 0     Geographic identifier code      Geographic Area Name  2012 NAICS code
# 1                 0500000US01001   Autauga County, Alabama               62
# 2                 0500000US01001   Autauga County, Alabama               62
# 3                 0500000US01001   Autauga County, Alabama               62
# 4                 0500000US01003   Baldwin County, Alabama               62
# ...                          ...                       ...              ...
# 9295              0500000US56043  Washakie County, Wyoming               62
# 9296              0500000US56043  Washakie County, Wyoming               62
# 9297              0500000US56045    Weston County, Wyoming               62
# 9298              0500000US56045    Weston County, Wyoming               62
# 9299              0500000US56045    Weston County, Wyoming               62
#
# ...

# %%
df_2017
# Out:
#                            GEO_ID                     NAME        NAICS2017  \
# 0      Geographic identifier code     Geographic Area Name  2017 NAICS code
# 1                  0500000US01001  Autauga County, Alabama               22
# 2                  0500000US01001  Autauga County, Alabama            31-33
# 3                  0500000US01001  Autauga County, Alabama               42
# 4                  0500000US01001  Autauga County, Alabama            44-45
# ...                           ...                      ...              ...
# 60748              0500000US56045   Weston County, Wyoming               62
# 60749              0500000US56045   Weston County, Wyoming               62
# 60750              0500000US56045   Weston County, Wyoming               72
# 60751              0500000US56045   Weston County, Wyoming               81
# 60752              0500000US56045   Weston County, Wyoming               81
#
# ...

# %%
df_2017.columns=df_2017.iloc[0].tolist()
df_2022.columns=df_2022.iloc[0].tolist()

# %%
df_2017=df_2017.iloc[1:,]
df_2022=df_2022.iloc[1:,]

# %%
df_2017.columns,df_2022.columns
# Out:
# (Index([                                                     'Geographic identifier code',
#                                                                    'Geographic Area Name',
#                                                                         '2017 NAICS code',
#                                                                   'Meaning of NAICS code',
#                                                                  'Type of operation code',
#                                                       'Meaning of Type of operation code',
#                                                                         'Tax status code',
#                                                              'Meaning of Tax status code',
#                                                                                    'Year',
#                                                                         'Number of firms',
# ...

# %%
df_2017['Type of operation code'].value_counts()
# Out:
# Type of operation code
# 00    57879
# 10     2873
# Name: count, dtype: int64

# %%
df_2017=df_2017[['Geographic Area Name','2017 NAICS code','Meaning of NAICS code','Year','Number of firms','Number of establishments']]
df_2022=df_2022[['Geographic Area Name','2022 NAICS code','Meaning of NAICS code','Year','Number of firms','Number of establishments']]
df_2022.rename(columns={'2022 NAICS code':'NAICS code'},inplace=True)
df_2017.rename(columns={'2017 NAICS code':'NAICS code'},inplace=True)
# Out:
# C:\Users\yesub\AppData\Local\Temp\ipykernel_53160\4279882074.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017.rename(columns={'2017 NAICS code':'NAICS code'},inplace=True)

# %%
df_2017
# Out:
#           Geographic Area Name  NAICS code  \
# 1      Autauga County, Alabama          22
# 2      Autauga County, Alabama       31-33
# 3      Autauga County, Alabama          42
# 4      Autauga County, Alabama       44-45
# 5      Autauga County, Alabama  48-49(106)
# ...                        ...         ...
# 60748   Weston County, Wyoming          62
# 60749   Weston County, Wyoming          62
# 60750   Weston County, Wyoming          72
# 60751   Weston County, Wyoming          81
# 60752   Weston County, Wyoming          81
#
#                                Meaning of NAICS code  Year Number of firms  \
# 1                                          Utilities  2017               4
# 2                                      Manufacturing  2017              23
# 3                                    Wholesale trade  2017              23
# 4                                       Retail trade  2017             155
# ...

# %%
df=pd.concat([df_2017,df_2022],ignore_index=True)

# %%
df
# Out:
#            Geographic Area Name  NAICS code  \
# 0       Autauga County, Alabama          22
# 1       Autauga County, Alabama       31-33
# 2       Autauga County, Alabama          42
# 3       Autauga County, Alabama       44-45
# 4       Autauga County, Alabama  48-49(106)
# ...                         ...         ...
# 263904   Weston County, Wyoming        6241
# 263905   Weston County, Wyoming        6241
# 263906   Weston County, Wyoming        6244
# 263907   Weston County, Wyoming       62441
# 263908   Weston County, Wyoming      624410
#
#                       Meaning of NAICS code  Year Number of firms  \
# 0                                 Utilities  2017               4
# 1                             Manufacturing  2017              23
# 2                           Wholesale trade  2017              23
# 3                              Retail trade  2017             155
# 4       Transportation and warehousing(106)  2017              17
# ...

# %%
ded=pd.read_csv('DisasterDeclarationsSummaries (1).csv',low_memory=False)

# %%
ded
# Out:
#       femaDeclarationString  disasterNumber state declarationType  \
# 0                FM-5530-NV            5530    NV              FM
# 1                FM-5529-OR            5529    OR              FM
# 2                FM-5528-OR            5528    OR              FM
# 3                FM-5527-OR            5527    OR              FM
# 4                FM-5522-CA            5522    CA              FM
# ...                     ...             ...   ...             ...
# 67358               DR-9-TX               9    TX              DR
# 67359               DR-8-IA               8    IA              DR
# 67360               DR-7-MA               7    MA              DR
# 67361               DR-2-TX               2    TX              DR
# 67362               DR-1-GA               1    GA              DR
#
#                 declarationDate  fyDeclared incidentType  \
# 0      2024-08-12T00:00:00.000Z        2024         Fire
# ...

# %%
ded.columns
# Out:
# Index(['femaDeclarationString', 'disasterNumber', 'state', 'declarationType',
#        'declarationDate', 'fyDeclared', 'incidentType', 'declarationTitle',
#        'ihProgramDeclared', 'iaProgramDeclared', 'paProgramDeclared',
#        'hmProgramDeclared', 'incidentBeginDate', 'incidentEndDate',
#        'disasterCloseoutDate', 'tribalRequest', 'fipsStateCode',
#        'fipsCountyCode', 'placeCode', 'designatedArea',
#        'declarationRequestNumber', 'lastIAFilingDate', 'incidentId', 'region',
#        'designatedIncidentTypes', 'lastRefresh', 'hash', 'id'],
#       dtype='object')

# %%
ded['declarationDate']=pd.to_datetime(ded['declarationDate'])

# %%
ded['Year']=ded['declarationDate'].dt.year

# %%
ded1322=ded[ded['Year'].between(2013,2022)]

# %%
ded1322['Year'].value_counts()
# Out:
# Year
# 2020    9712
# 2021    1962
# 2017    1668
# 2019    1666
# 2016    1194
# 2018    1184
# 2022    1141
# 2015     963
# 2013     771
# 2014     689
# Name: count, dtype: int64

# %%
ded1322.loc[ded1322['Year1'].isin([2013, 2014, 2015, 2016]), 'Year'] = 2017
ded1322.loc[ded1322['Year1'].isin([2018,2019,2020,2021]),'Year']=2022
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[486], line 1
# ...

# %%
ded1322.reset_index(drop=True)
# Out:
#       femaDeclarationString  disasterNumber state declarationType  \
# 0                FM-5456-WA            5456    WA              FM
# 1                FM-5456-WA            5456    WA              FM
# 2                FM-5455-WA            5455    WA              FM
# 3                FM-5455-WA            5455    WA              FM
# 4                FM-5454-OR            5454    OR              FM
# ...                     ...             ...   ...             ...
# 20945            DR-4122-AK            4122    AK              DR
# 20946            DR-4122-AK            4122    AK              DR
# 20947            DR-4122-AK            4122    AK              DR
# 20948            DR-4122-AK            4122    AK              DR
# 20949            DR-4122-AK            4122    AK              DR
#
#                 declarationDate  fyDeclared incidentType  declarationTitle  \
# 0     2022-10-17 00:00:00+00:00        2023         Fire  NAKIA CREEK FIRE
# ...

# %%
ded1322['Year'].value_counts()
# Out:
# Year
# 2020    9712
# 2021    1962
# 2017    1668
# 2019    1666
# 2016    1194
# 2018    1184
# 2022    1141
# 2015     963
# 2013     771
# 2014     689
# Name: count, dtype: int64

# %%
ded1322['designatedArea'].split('(')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_53160\2024128449.py in ?()
# ----> 1 ded1322['designatedArea'].split('(')
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
ded1322.groupby(['designatedArea',])
# Out:
#   Cell In[492], line 1
#     ded1322.groupby['
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df
# Out:
#            Geographic Area Name  NAICS code  \
# 0       Autauga County, Alabama          22
# 1       Autauga County, Alabama       31-33
# 2       Autauga County, Alabama          42
# 3       Autauga County, Alabama       44-45
# 4       Autauga County, Alabama  48-49(106)
# ...                         ...         ...
# 263904   Weston County, Wyoming        6241
# 263905   Weston County, Wyoming        6241
# 263906   Weston County, Wyoming        6244
# 263907   Weston County, Wyoming       62441
# 263908   Weston County, Wyoming      624410
#
#                       Meaning of NAICS code  Year Number of firms  \
# 0                                 Utilities  2017               4
# 1                             Manufacturing  2017              23
# 2                           Wholesale trade  2017              23
# 3                              Retail trade  2017             155
# 4       Transportation and warehousing(106)  2017              17
# ...

# %%
df_2017=df_2017.drop(0,axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[462], line 1
# ----> 1 df_2017=df_2017.drop(0,axis=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df_2017
# Out:
#           Geographic Area Name  NAICS code  \
# 1      Autauga County, Alabama          22
# 2      Autauga County, Alabama       31-33
# 3      Autauga County, Alabama          42
# 4      Autauga County, Alabama       44-45
# 5      Autauga County, Alabama  48-49(106)
# ...                        ...         ...
# 60748   Weston County, Wyoming          62
# 60749   Weston County, Wyoming          62
# 60750   Weston County, Wyoming          72
# 60751   Weston County, Wyoming          81
# 60752   Weston County, Wyoming          81
#
#                                Meaning of NAICS code  Year Number of firms  \
# 1                                          Utilities  2017               4
# 2                                      Manufacturing  2017              23
# 3                                    Wholesale trade  2017              23
# 4                                       Retail trade  2017             155
# ...
